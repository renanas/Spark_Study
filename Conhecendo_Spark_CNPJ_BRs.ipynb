# %% [markdown]
# <a href="https://colab.research.google.com/github/renanas/Spark_Study/blob/main/Conhecendo_Spark_CNPJ_BRs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz
# !tar xf spark-3.1.2-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"

# %%
import findspark

findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .master('local[*]') \
        .appName("Iniciando o Spark") \
        .config('spark.ui.port', '4050') \
        .getOrCreate()

# %%
# !wget -q https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok config add-authtoken 2bx5Jvam88i1KRy6qH5AS6aS5ef_6MPtvbmdUJnfvSvf8tHY9')
get_ipython().system_raw('./ngrok authtoken 2bx5Jvam88i1KRy6qH5AS6aS5ef_6MPtvbmdUJnfvSvf8tHY9')
get_ipython().system_raw('./ngrok http 4050 &')

# %%
# !curl -s http://localhost:4040/api/tunnels
# Out:
# {"tunnels":[],"uri":"/api/tunnels"}

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://4805756938b9:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Iniciando o Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# %%
zipfile.ZipFile('/content/drive/MyDrive/Databases/curso-spark-alura/empresas.zip', 'r') \
.extractall('/content/drive/MyDrive/Databases/curso-spark-alura')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-12-438246ebd61b> in <cell line: 1>()
# ----> 1 zipfile.ZipFile('/content/drive/MyDrive/Databases/curso-spark-alura/empresas.zip', 'r') \
#       2 .extractall('/content/drive/MyDrive/Databases/curso-spark-alura')
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
#    1268             if mode == 'r':
# -> 1269                 self._RealGetContents()
#    1270             elif mode in ('w', 'x'):
#    1271                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.10/zipfile.py in _RealGetContents(self)
#    1334             raise BadZipFile("File is not a zip file")
#    1335         if not endrec:
# -> 1336             raise BadZipFile("File is not a zip file")
# ...

# %%
path = '/content/drive/MyDrive/Databases/curso-spark-alura/empresas' # Caminho da pasta empresa
empresas = spark.read.csv(path, sep=';', inferSchema=True)

# %%
empresas.count()
# Out:
# 4585679

# %%
empresas.limit(5).toPandas()
# Out:
#     _c0                                                _c1   _c2  _c3  \
# 0   306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA  2240   49
# 1  1355                         BRASILEIRO & OLIVEIRA LTDA  2062   49
# 2  4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...  3034   32
# 3  5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS  2135   50
# 4  6846                         BADU E FILHOS TECIDOS LTDA  2062   49
#
#        _c4  _c5   _c6
# 0     0,00    1  None
# 1     0,00    5  None
# 2     0,00    5  None
# 3     0,00    5  None
# 4  4000,00    1  None

# %%
empresasColNames = ['cnpj_basico', 'razao_social_nome_empresarial', 'natureza_juridica', 'qualificacao_do_responsavel', 'capital_social_da_empresa', 'porte_da_empresa', 'ente_federativo_responsavel']

# %%
for index, colName in enumerate(empresasColNames):
  empresas = empresas.withColumnRenamed(f"_c{index}", colName)

empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %% [markdown]
# # Fazendo o mesmo para socios

# %%
# SOCIOS

zipfile.ZipFile('/content/drive/MyDrive/Databases/curso-spark-alura/socios.zip', 'r') \
.extractall('/content/drive/MyDrive/Databases/curso-spark-alura')

path = '/content/drive/MyDrive/Databases/curso-spark-alura/socios' # Caminho da pasta empresa
socios = spark.read.csv(path, sep=';', inferSchema=True)
socios.count()
# Out:
# 2046430

# %%
socios.limit(5).toPandas()
# Out:
#      _c0  _c1                              _c2          _c3  _c4       _c5  \
# 0    411    2      LILIANA PATRICIA GUASTAVINO  ***678188**   22  19940725
# 1    411    2             CRISTINA HUNDERTMARK  ***637848**   28  19940725
# 2   5813    2  CELSO EDUARDO DE CASTRO STEPHAN  ***786068**   49  19940516
# 3   5813    2        EDUARDO BERRINGER STEPHAN  ***442348**   49  19940516
# 4  14798    2              HANNE MAHFOUD FADEL  ***760388**   49  19940609
#
#    _c6          _c7   _c8  _c9  _c10
# 0  NaN  ***000000**  None    0     7
# 1  NaN  ***000000**  None    0     7
# 2  NaN  ***000000**  None    0     8
# 3  NaN  ***000000**  None    0     5
# 4  NaN  ***000000**  None    0     8

# %%
sociosColNames = ['cnpj_basico', 'identificador_de_socio', 'nome_do_socio_ou_razao_social', 'cnpj_ou_cpf_do_socio', 'qualificacao_do_socio', 'data_de_entrada_sociedade', 'pais', 'representante_legal', 'nome_do_representante', 'qualificacao_do_representante_legal', 'faixa_etaria']

# %%
for index, colName in enumerate(sociosColNames):
  socios = socios.withColumnRenamed(f"_c{index}", colName)

socios.columns
# Out:
# ['cnpj_basico',
#  'identificador_de_socio',
#  'nome_do_socio_ou_razao_social',
#  'cnpj_ou_cpf_do_socio',
#  'qualificacao_do_socio',
#  'data_de_entrada_sociedade',
#  'pais',
#  'representante_legal',
#  'nome_do_representante',
#  'qualificacao_do_representante_legal',
#  'faixa_etaria']

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %% [markdown]
# # Analisando dados

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: integer (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %% [markdown]
# # Modificando a base de empresas

# %%
# Convertendo string para double
from pyspark.sql.types import DoubleType, StringType
from pyspark.sql import functions as f

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas = empresas.withColumn('capital_social_da_empresa', f.regexp_replace('capital_social_da_empresa', ',', '.'))
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0.00
# 1               2062                           49                      0.00
# 2               3034                           32                      0.00
# 3               2135                           50                      0.00
# 4               2062                           49                   4000.00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas = empresas.withColumn('capital_social_da_empresa', empresas['capital_social_da_empresa'].cast(DoubleType()))
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel  capital_social_da_empresa  \
# 0               2240                           49                        0.0
# 1               2062                           49                        0.0
# 2               3034                           32                        0.0
# 3               2135                           50                        0.0
# 4               2062                           49                     4000.0
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %% [markdown]
# # Modificando base de Socios

# %%
# Convertendo integer para string (data_de_entrada_sociedade está em inteiro)

socios = socios\
  .withColumn(
      "data_de_entrada_sociedade",
      f.to_date(socios.data_de_entrada_sociedade.cast(StringType()), 'yyyyMMdd')
  )
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %% [markdown]
# # Seleções e consultas

# %%
empresas\
  .select('*')\
  .show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
# O segundo parametro do show é o truncated
empresas\
  .select('*')\
  .show(5, False)
# Out:
# +-----------+--------------------------------------------------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial                                                               |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+--------------------------------------------------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |306        |FRANCAMAR REFRIGERACAO TECNICA S/C LTDA                                                     |2240             |49                         |0.0                      |1               |null                       |
# ...

# %%
empresas\
  .select('natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
  .show(5)
# Out:
# +-----------------+----------------+-------------------------+
# |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +-----------------+----------------+-------------------------+
# |             2240|               1|                      0.0|
# |             2062|               5|                      0.0|
# |             3034|               5|                      0.0|
# |             2135|               5|                      0.0|
# |             2062|               1|                   4000.0|
# +-----------------+----------------+-------------------------+
# only showing top 5 rows

# %%
socios\
  .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
  .show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994          |
# |CRISTINA HUNDERTMARK           |7           |1994          |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994          |
# |EDUARDO BERRINGER STEPHAN      |5           |1994          |
# |HANNE MAHFOUD FADEL            |8           |1994          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %% [markdown]
# # Identificando valores nulos

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.select([f.count(f.when(f.isnull(coluna), 1)).alias(coluna) for coluna in socios.columns]).show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|   pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |          0|                     0|                          208|                1234|                    0|                        1|2038255|                  0|              1995432|                                  0|           0|
# ...

# %%
socios.na.fill(0).limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25     0
# 1          ***637848**                     28                1994-07-25     0
# 2          ***786068**                     49                1994-05-16     0
# 3          ***442348**                     49                1994-05-16     0
# 4          ***760388**                     49                1994-06-09     0
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.na.fill('-').limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %% [markdown]
# # Ordenando os dados

# %%
socios\
    .select('nome_do_socio_ou_razao_social',
            'faixa_etaria',
            f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994          |
# |CRISTINA HUNDERTMARK           |7           |1994          |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994          |
# |EDUARDO BERRINGER STEPHAN      |5           |1994          |
# |HANNE MAHFOUD FADEL            |8           |1994          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %%
socios\
    .select('nome_do_socio_ou_razao_social',
            'faixa_etaria',
            f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .orderBy('ano_de_entrada', ascending=False)\
    .show(5, False)
# Out:
# +----------------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social           |faixa_etaria|ano_de_entrada|
# +----------------------------------------+------------+--------------+
# |KASSIANO RODRIGO KICHILESKI             |4           |2021          |
# |LEONARDO MENNA BARRETO LARANJA GONCALVES|5           |2021          |
# |MANOEL ADRIANO COSTA BARBOSA            |6           |2021          |
# |ANTONOALDO GRANGEON TRANCOSO NEVES      |5           |2021          |
# |MARIA SUELY DE MOURA                    |5           |2021          |
# +----------------------------------------+------------+--------------+
# only showing top 5 rows

# %%
socios\
    .select('nome_do_socio_ou_razao_social',
            'faixa_etaria',
            f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .orderBy(['ano_de_entrada', 'faixa_etaria'], ascending=[False, False])\
    .show(5, False)
# Out:
# +-----------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social|faixa_etaria|ano_de_entrada|
# +-----------------------------+------------+--------------+
# |EDGAR FRANCISCO DA SILVA     |9           |2021          |
# |WILLIAM WHITING BEACH VEALE  |9           |2021          |
# |ANTONIO TAVARES DE ANDRADE   |9           |2021          |
# |AURA MARIA DE ANDRADE        |9           |2021          |
# |ANTONIA DE SOUSA VIEIRA      |9           |2021          |
# +-----------------------------+------------+--------------+
# only showing top 5 rows

# %%
socios\
    .select('nome_do_socio_ou_razao_social',
            'faixa_etaria',
            f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .orderBy(['ano_de_entrada', 'faixa_etaria'], ascending=[False, True])\
    .show(5, False)
# Out:
# +-------------------------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social                    |faixa_etaria|ano_de_entrada|
# +-------------------------------------------------+------------+--------------+
# |TEXTIL RIO DOS CEDROS LTDA                       |0           |2021          |
# |FIO E FERRO MATERIAIS SERVICOS E CONSTRUCOES LTDA|0           |2021          |
# |QB PROSPERITY PARTICIPACOES LTDA                 |0           |2021          |
# |MELNICK EVEN PARTICIPACOES SOCIETARIAS LTDA      |0           |2021          |
# |PARATI NEG�CIOS IMOBILI�RIOS LTDA                |0           |2021          |
# +-------------------------------------------------+------------+--------------+
# only showing top 5 rows

# %% [markdown]
# # Filtrando Dados

# %%
empresas\
  .where("capital_social_da_empresa==50")\
  .show(5, False)
# Out:
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial       |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |17350147   |ERIK MARCELO DOS SANTOS 42107848858 |2135             |50                         |50.0                     |1               |null                       |
# |17833214   |ALEXANDRE MACHADO LIMA 73750123772  |2135             |50                         |50.0                     |1               |null                       |
# ...

# %%
socios\
  .select("nome_do_socio_ou_razao_social")\
  .filter(socios.nome_do_socio_ou_razao_social.startswith("RENAN"))\
  .filter(socios.nome_do_socio_ou_razao_social.endswith("SILVA"))\
  .limit(10)\
  .toPandas()
# Out:
#     nome_do_socio_ou_razao_social
# 0     RENAN RAMBO GASPAR DA SILVA
# 1             RENAN FREITAS SILVA
# 2            RENAN MUNIZ DA SILVA
# 3            RENAN SIMOA DA SILVA
# 4        RENAN FERNANDES DA SILVA
# 5  RENAN GONTIJO SANTANA DA SILVA
# 6  RENAN GONCALVES RAMOS DA SILVA
# 7         RENAN FERREIRA DA SILVA
# 8           RENAN DE CASTRO SILVA
# 9         RENAN LOURENCO DA SILVA

# %% [markdown]
# # O comando LIKE

# %%
socios\
  .where(f.upper(socios.nome_do_socio_ou_razao_social).like('%SILVA%'))\
  .show(truncate=False)
# Out:
# +-----------+----------------------+--------------------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social         |cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+--------------------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |221761     |2                     |ALBERTO SOETHE LEPASKY DA SILVA       |***994529**         |28                   |1995-07-06               |null|***000000**        |null                 |0                                  |8           |
# ...

# %%
empresas\
  .select('razao_social_nome_empresarial', 'natureza_juridica', 'porte_da_empresa')\
  .filter(f.upper(empresas['razao_social_nome_empresarial']).like('%RESTAURANTES%'))\
  .show(10, False)
# Out:
# +---------------------------------------+-----------------+----------------+
# |razao_social_nome_empresarial          |natureza_juridica|porte_da_empresa|
# +---------------------------------------+-----------------+----------------+
# |A M DA MOTA RESTAURANTES E SIMILARES   |2135             |1               |
# |COMERCIAL BONZAO RESTAURANTES LTDA     |2062             |1               |
# |SANTJOUG RESTAURANTES EIRELI           |2305             |1               |
# |J L DE QUEIROZ RESTAURANTES            |2135             |1               |
# |UAC RESTAURANTES LTDA                  |2062             |3               |
# |RESTAURANTES E PIZZARIAS ARCO IRIS LTDA|2062             |1               |
# |HOTEIS E RESTAURANTES IZOLAN LTDA      |2062             |1               |
# |MARUJO'S RESTAURANTES LTDA             |2062             |1               |
# |RISE RESTAURANTES LTDA                 |2062             |5               |
# ...

# %% [markdown]
# # Sumarizando os dados

# %%
socios\
  .select(f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
  .where('ano_de_entrada >= 2010')\
  .groupBy('ano_de_entrada')\
  .count()\
  .orderBy('ano_de_entrada', ascending=True)\
  .show()
# Out:
# +--------------+------+
# |ano_de_entrada| count|
# +--------------+------+
# |          2010| 79337|
# |          2011| 83906|
# |          2012| 80101|
# |          2013| 83919|
# |          2014| 80590|
# |          2015| 80906|
# |          2016| 81587|
# |          2017| 90221|
# |          2018| 99935|
# |          2019|118248|
# |          2020|125927|
# |          2021| 56316|
# +--------------+------+

# %%
empresas\
  .select('cnpj_basico', 'porte_da_empresa', 'capital_social_da_empresa')\
  .groupBy('porte_da_empresa')\
  .agg(
      f.avg("capital_social_da_empresa").alias("capital_social_medio"),
      f.count("cnpj_basico").alias("frequencia")
  )\
  .orderBy('porte_da_empresa', ascending=True)\
  .show()
# Out:
# +----------------+--------------------+----------+
# |porte_da_empresa|capital_social_medio|frequencia|
# +----------------+--------------------+----------+
# |            null|    8.35421888053467|      5985|
# |               1|  339994.53313506936|   3129043|
# |               3|  2601001.7677092673|    115151|
# |               5|   708660.4208249798|   1335500|
# +----------------+--------------------+----------+

# %%
empresas\
  .select("capital_social_da_empresa")\
  .summary()\
  .show()
# Out:
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542675|
# | stddev|     2.1118691490537405E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %% [markdown]
# # Juntando DataFrames

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
empresas_join = socios.join(empresas, 'cnpj_basico', how='inner')

# %%
empresas_join.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
freq = empresas_join\
    .select(
        'cnpj_basico',
        f.year('data_de_entrada_sociedade').alias('data_de_entrada_sociedade')
    )\
    .where('data_de_entrada_sociedade >= 2010')\
    .groupBy('data_de_entrada_sociedade')\
    .agg(f.count("cnpj_basico").alias("frequencia"))\
    .orderBy('data_de_entrada_sociedade', ascending=True)

# %%
freq.toPandas()
# Out:
#     data_de_entrada_sociedade  frequencia
# 0                        2010       79337
# 1                        2011       83906
# 2                        2012       80101
# 3                        2013       83919
# 4                        2014       80590
# 5                        2015       80906
# 6                        2016       81593
# 7                        2017       90225
# 8                        2018       99935
# 9                        2019      118248
# 10                       2020      125931
# 11                       2021       56316

# %%
freq.union(
    freq.select(
        f.lit('Total').alias('data_de_entrada_sociedade'),
        f.sum(freq.frequencia).alias('frequencia')
    )
).show()
# Out:
# +-------------------------+----------+
# |data_de_entrada_sociedade|frequencia|
# +-------------------------+----------+
# |                     2010|     79337|
# |                     2011|     83906|
# |                     2012|     80101|
# |                     2013|     83919|
# |                     2014|     80590|
# |                     2015|     80906|
# |                     2016|     81593|
# |                     2017|     90225|
# |                     2018|     99935|
# |                     2019|    118248|
# |                     2020|    125931|
# |                     2021|     56316|
# |                    Total|   1061007|
# +-------------------------+----------+

# %% [markdown]
# # SparkSQL
#
# https://community.cloudera.com/t5/Community-Articles/Spark-RDDs-vs-DataFrames-vs-SparkSQL/ta-p/246547

# %%
empresas.createOrReplaceTempView("empresasView")

# %%
spark.sql("SELECT * FROM empresasView").show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
spark\
  .sql("""
      SELECT *
        FROM empresasView
        WHERE capital_social_da_empresa = 50
  """ )\
  .show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |   17350147|         ERIK MARCELO DOS ...|             2135|                         50|                     50.0|               1|                       null|
# |   17833214|         ALEXANDRE MACHADO...|             2135|                         50|                     50.0|               1|                       null|
# |   20860830|         YASMIN MOURA DA F...|             2135|                         50|                     50.0|               1|                       null|
# ...

# %%
spark\
  .sql("""
      SELECT porte_da_empresa, MEAN(capital_social_da_empresa) as Media
        FROM empresasView
        GROUP BY porte_da_empresa
  """ )\
  .show(5)
# Out:
# +----------------+------------------+
# |porte_da_empresa|             Media|
# +----------------+------------------+
# |            null|  8.35421888053467|
# |               1|339994.53313506936|
# |               3|2601001.7677092673|
# |               5| 708660.4208249798|
# +----------------+------------------+

# %% [markdown]
# outra forma de fazer a frequencia

# %%
empresas_join.createOrReplaceTempView("empresasJoinView")

# %%
freq = spark\
    .sql("""
        SELECT YEAR(data_de_entrada_sociedade) AS data_de_entrada_sociedade, COUNT(cnpj_basico) AS count
            FROM empresasJoinView
            WHERE YEAR(data_de_entrada_sociedade) >= 2010
            GROUP BY data_de_entrada_sociedade
            ORDER BY data_de_entrada_sociedade
    """)

freq\
    .show()
# Out:
# +-------------------------+-----+
# |data_de_entrada_sociedade|count|
# +-------------------------+-----+
# |                     2010|    3|
# |                     2010|   10|
# |                     2010|  211|
# |                     2010|  254|
# |                     2010|  223|
# |                     2010|  249|
# |                     2010|  234|
# |                     2010|    1|
# |                     2010|    4|
# |                     2010|  276|
# |                     2010|  275|
# |                     2010|  257|
# |                     2010|  312|
# |                     2010|  230|
# |                     2010|    1|
# |                     2010|  241|
# |                     2010|  321|
# |                     2010|  240|
# |                     2010|  329|
# |                     2010|  270|
# +-------------------------+-----+
# only showing top 20 rows

# %%
freq.createOrReplaceTempView("freqView")

# %%
spark\
    .sql("""
        SELECT *
            FROM freqView
        UNION ALL
        SELECT 'Total' AS data_de_inicio, SUM(count) AS count
            FROM freqView
    """)\
    .show()
# Out:
# +-------------------------+-----+
# |data_de_entrada_sociedade|count|
# +-------------------------+-----+
# |                     2010|    3|
# |                     2010|   10|
# |                     2010|  211|
# |                     2010|  254|
# |                     2010|  223|
# |                     2010|  249|
# |                     2010|  234|
# |                     2010|    1|
# |                     2010|    4|
# |                     2010|  276|
# |                     2010|  275|
# |                     2010|  257|
# |                     2010|  312|
# |                     2010|  230|
# |                     2010|    1|
# |                     2010|  241|
# |                     2010|  321|
# |                     2010|  240|
# |                     2010|  329|
# |                     2010|  270|
# +-------------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # Formas de armazenamento

# %%
empresas.write.csv(
    path='/content/drive/MyDrive/Databases/curso-spark-alura/empresas/csv',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
socios.write.csv(
    path='/content/drive/MyDrive/Databases/curso-spark-alura/socios/csv',
    mode='overwrite',
    sep=';',
    header=True
)

# %% [markdown]
# # Arquivos PARQUET

# %%
empresas.write.parquet(
    path='/content/drive/MyDrive/Databases/curso-spark-alura/empresas/parquet',
    mode='overwrite'
)

# %%
socios.write.parquet(
    path='/content/drive/MyDrive/Databases/curso-spark-alura/socios/parquet',
    mode='overwrite'
)

# %%
spark.stop()
